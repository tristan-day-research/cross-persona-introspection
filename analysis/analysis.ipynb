# %% [markdown]
# # PSM Introspection Analysis
#
# Load and analyze experiment results.

# %%
import sys
sys.path.insert(0, '..')

from cross_persona_introspection.core.results_logger import load_results
from analysis.summarize import summarize_cross_persona, summarize_source_reporter, print_summary

# If imports fail from the notebook's location, try:
# sys.path.insert(0, '/Users/daylight/dev/code/cross_persona_introspection')

# %% [markdown]
# ## Cross-Persona Prediction Results

# %%
# Update path to your results file
# df = load_results('results/raw/cross_persona_XXXXXXXX_XXXXXX.jsonl')
# print_summary(summarize_cross_persona('results/raw/cross_persona_XXXXXXXX_XXXXXX.jsonl'))

# %% [markdown]
# ## Source × Reporter Matrix Results

# %%
# Update path to your results file
# df = load_results('results/raw/source_reporter_XXXXXXXX_XXXXXX.jsonl')
# print_summary(summarize_source_reporter('results/raw/source_reporter_XXXXXXXX_XXXXXX.jsonl'))
